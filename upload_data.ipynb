# %%
import pandas as pd

df=pd.read_csv('yellow_tripdata_2023-01.csv',nrows=100)

# %%
df.tpep_pickup_datetime=pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime=pd.to_datetime(df.tpep_dropoff_datetime)

# %%
print(pd.io.sql.get_schema(df,name='yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %%
from sqlalchemy import  create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
df_iter=pd.read_csv('yellow_tripdata_2023-01.csv', iterator=True, chunksize=100000 ,parse_dates=['tpep_pickup_datetime', 'tpep_dropoff_datetime'])

# %%
from time import time

# %%
while True:

    t_start=time()

    df=next(df_iter)

    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')

    t_end=time()

    print(f'inserted another chunk..., took {t_end - t_start:.3f} seconds')
# Out:
# inserted another chunk..., took 8.633 seconds
# inserted another chunk..., took 7.746 seconds
# inserted another chunk..., took 7.675 seconds
# inserted another chunk..., took 8.249 seconds
# inserted another chunk..., took 8.585 seconds
# inserted another chunk..., took 8.108 seconds
# inserted another chunk..., took 8.014 seconds
# inserted another chunk..., took 7.925 seconds
# inserted another chunk..., took 9.694 seconds
# inserted another chunk..., took 10.276 seconds
# inserted another chunk..., took 8.251 seconds
# inserted another chunk..., took 7.939 seconds
# inserted another chunk..., took 8.070 seconds
# inserted another chunk..., took 8.907 seconds
# inserted another chunk..., took 8.285 seconds
# inserted another chunk..., took 9.764 seconds
# inserted another chunk..., took 8.737 seconds
# inserted another chunk..., took 7.983 seconds
# inserted another chunk..., took 8.081 seconds
# inserted another chunk..., took 7.950 seconds
# ...

# %%
import pandas as pd

pd.read_parquet('/Users/jayesh/downloads/yellow_tripdata_2023-01.parquet')
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0  \
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...
